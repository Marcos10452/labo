# %%
import datatable as dt
import numpy as np
import pandas as pd
from pandas_summary import DataFrameSummary

import os
path="/home/marcos/DataScience/Curso/MdD/"
os.chdir(path)
#To check working directory

os.getcwd()
# Out:
# '/home/marcos/DataScience/Curso/MdD'

# %%
DT = dt.fread("./datasets/competencia1_2022.csv")

# %%
DT.head()
# Out:
# <Frame#7f61c88a67b0 10x155>

# %%
df=DT.to_pandas()

# %%
display(df.head())
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0           31115668    202101            True        False         0
# 1           31115678    202101            True        False         0
# 2           31117415    202101            True        False         0
# 3           31117711    202101            True        False         0
# 4           31118145    202101            True        False         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            56                 132        1897.12              24324.75
# 1            48                 100        -384.72              33860.45
# 2            60                  53       -3622.66             -21310.32
# 3            46                 273       14542.05             125727.99
# 4            47                 192        1868.27              37305.29
#
#    mcomisiones  ...  Visa_fultimo_cierre  Visa_mpagado  Visa_mpagospesos  \
# ...

# %%
display(DataFrameSummary(df).summary())
# Out:
#              numero_de_cliente       foto_mes active_quarter cliente_vip  \
# count                 324242.0       324242.0            NaN         NaN
# mean          101298735.092625  202102.004805            NaN         NaN
# std             43455369.12989        0.99999            NaN         NaN
# min                 31115668.0       202101.0            NaN         NaN
# 25%                67385377.25       202101.0            NaN         NaN
# 50%                 96202094.0       202103.0            NaN         NaN
# 75%                132200932.0       202103.0            NaN         NaN
# max                212524211.0       202103.0            NaN         NaN
# counts                  324242         324242         324242      324242
# uniques                 164413              2              2           2
# missing                      0              0              0           0
# missing_perc                0%             0%             0%          0%
# ...

# %%
DataFrameSummary(df).summary().loc[['uniques', 'types', 'missing']].T
# Out:
#                         uniques        types missing
# numero_de_cliente        164413      numeric       0
# foto_mes                      2         bool       0
# active_quarter                2         bool       0
# cliente_vip                   2         bool       0
# internet                      5      numeric       0
# ...                         ...          ...     ...
# Visa_mconsumototal       220254      numeric   44255
# Visa_cconsumos              137      numeric   44255
# Visa_cadelantosefectivo      14      numeric   44255
# Visa_mpagominimo           8033      numeric   15718
# clase_ternaria                4  categorical       0
#
# [155 rows x 3 columns]

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# Matrix cov
df2=df[["ctrx_quarter","mcaja_ahorro","cpayroll_trx","mpasivos_margen","mcuentas_saldo","mprestamos_personales","mtarjeta_visa_consumo","mrentabilidad_annual","mpayroll"]]

# %%
covMatrix = pd.DataFrame.corr(df2)

# %%
plt.figure(figsize=(20,20))
sn.heatmap(covMatrix, annot=True, fmt='g')

plt.show()
